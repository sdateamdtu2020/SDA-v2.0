# %%
import sys
import os
import time
import pandas as pd
import math
import numpy

# %%
def get_files_data():
    path = "./data/"
    files = os.listdir(path)
    files.sort()

    return files

# %%
data = get_files_data()

df = pd.read_excel(r'data/{}'.format(data[1]), skiprows=1)

current = df.loc[0]

year_data = []


transformed_data = 0
for i in range(1,len(current)):
    if type(current[i]) is str:
        transformed_data = int((current[i])[:-5:-1][::-1])
    else:
        transformed_data = int(current[i])
    year_data.append(transformed_data)
        
    
print(year_data)
# Out:
# [2010, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019]

# %%
print(current)
# Out:
# Unnamed: 0           NaN
# Unnamed: 1          2010
# Unnamed: 2          2012
# Unnamed: 3          2013
# Unnamed: 4          2014
# Unnamed: 5          2015
# Unnamed: 6          2016
# Unnamed: 7          2017
# Unnamed: 8          2018
# Unnamed: 9    Sơ bộ 2019
# Name: 0, dtype: object

# %%
current3 = df[current2[0]]

city_data = []
for i in range(1, len(current3)):
    city_data.append(current3[i])

print(current3)
# Out:
# 0                     NaN
# 1     Đồng bằng sông Hồng
# 2                  Hà Nội
# 3               Vĩnh Phúc
# 4                Bắc Ninh
#              ...
# 65                Cần Thơ
# 66              Hậu Giang
# 67              Sóc Trăng
# 68               Bạc Liêu
# 69                 Cà Mau
# Name: Unnamed: 0, Length: 70, dtype: object

# %%
files_data = []

for i in range(1, len(current3)):
    temp = df.loc[i]
    file_data = []
    for j in range(1, len(current)):
        file_data.append(temp[j])
    files_data.append(file_data)
    
print(files_data)
# Out:
# [[18.4, 18.4, 18.3, 17.7, 17.5, 17.1, 16.9, 16.8, 16.5], [15.5, 15.7, 15.8, 15.2, 15.2, 14.9, 14.7, 14.6, 14.4], [18.9, 20.6, 20.3, 19.7, 19.3, 19.0, 18.7, 18.6, 18.3], [19.3, 20.6, 20.2, 19.6, 19.2, 18.9, 18.6, 18.5, 18.2], [23.8, 24.0, 23.8, 23.0, 22.7, 22.3, 21.9, 21.8, 21.4], [18.3, 18.5, 18.5, 17.8, 17.5, 17.2, 17.0, 16.8, 16.5], [17.2, 19.1, 18.9, 18.3, 18.0, 17.6, 17.4, 17.3, 17], [19.3, 19.5, 19.3, 18.6, 18.3, 18.0, 17.7, 17.6, 17.3], [17.2, 16.4, 16.1, 15.6, 15.3, 15.1, 14.8, 14.8, 14.5], [23.6, 18.9, 18.9, 18.3, 18.0, 17.7, 17.4, 17.3, 17], [19.8, 20.1, 19.8, 19.1, 18.8, 18.5, 18.2, 18.1, 17.7], [23.1, 22.7, 22.6, 21.9, 21.5, 21.1, 20.8, 20.7, 20.3], [36.9, 35.7, 35.2, 33.9, 33.4, 32.5, 32.4, 32.5, 31.5], [57.6, 55.4, 54.6, 52.7, 51.8, 50.8, 50.0, 49.7, 48.9], [43.1, 38.4, 38.2, 36.9, 36.3, 35.6, 35.1, 34.9, 34.2], [29.4, 28.2, 27.9, 27.0, 26.5, 26.0, 25.6, 25.5, 24.9], [28.7, 28.6, 28.4, 27.5, 28.0, 27.5, 27.1, 26.9, 26.5], [48.6, 46.5, 46.4, 44.8, 44.0, 43.2, 42.5, 42.2, 
# ...
